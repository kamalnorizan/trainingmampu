# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame({'value1':randn(1000), 'value2':randn(1000), 'value3':randn(1000), 'value4':randn(1000)}, index = pd.date_range('2021-01-01', periods = 1000), columns=['value1', 'value2', 'value3', 'value4'])

# %%
df['value1']=df['value1'].cumsum()
df['value2']=df['value2'].cumsum()
df['value3']=df['value3'].cumsum()
df['value4']=df['value4'].cumsum()

df
# Out:
#                value1    value2    value3     value4
# 2021-01-01   1.174201 -1.462902  2.525387   0.641410
# 2021-01-02   2.162011 -1.341520  2.331199   0.053653
# 2021-01-03   1.924876 -0.993032 -0.479045  -1.350850
# 2021-01-04   2.270976 -0.549027  0.107057  -2.552716
# 2021-01-05   1.841462 -0.133701  0.687865  -4.338594
# ...               ...       ...       ...        ...
# 2023-09-23  77.422934 -2.375496  1.867747 -32.659551
# 2023-09-24  77.214909 -3.167576  1.777332 -32.976660
# 2023-09-25  75.582540 -4.624115  0.810430 -32.047182
# 2023-09-26  74.183246 -5.572275  1.683939 -31.350403
# 2023-09-27  74.502282 -6.042368  3.018311 -31.274733
#
# [1000 rows x 4 columns]

# %%
ts = pd.Series(randn(1000), pd.date_range('2021-01-01', periods = 1000))

# %%
ts
# Out:
# 2021-01-01    0.975692
# 2021-01-02    0.193501
# 2021-01-03    1.502287
# 2021-01-04   -0.390225
# 2021-01-05    0.773782
#                 ...
# 2023-09-23    1.303540
# 2023-09-24    0.038236
# 2023-09-25   -0.628242
# 2023-09-26    0.119552
# 2023-09-27   -0.279946
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()
ts
# Out:
# 2021-01-01     0.975692
# 2021-01-02     1.169193
# 2021-01-03     2.671480
# 2021-01-04     2.281255
# 2021-01-05     3.055037
#                 ...
# 2023-09-23   -25.375269
# 2023-09-24   -25.337033
# 2023-09-25   -25.965276
# 2023-09-26   -25.845724
# 2023-09-27   -26.125670
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts.plot(figsize = (14,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (14,5))
# Out:
# <AxesSubplot:>
