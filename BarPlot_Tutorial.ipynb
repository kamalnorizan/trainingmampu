# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import randn

# %%
df = sns.load_dataset('iris')
df = df.drop(['species'], axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %% [markdown]
# titanic['pclass'].plot(kind='hist')

# %%
titanic['survived'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Stacked Plot

# %%
df = pd.DataFrame(randn(10, 4), columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.789873 -0.279090 -0.073126 -0.144016
# 1 -1.073413  0.539372 -1.980382 -0.155633
# 2  1.444905 -0.286589  0.089124  0.618263
# 3 -0.989048  0.366496  0.366710 -0.886597
# 4 -0.158315  1.234150 -2.260861 -0.250485
# 5 -0.680543  1.769154  0.479883 -0.799829
# 6 -0.420079 -0.044555 -0.719077  1.293920
# 7 -0.608142 -0.063218 -0.624348  0.134243
# 8 -0.154030 -1.403449 -0.762853  1.919565
# 9  0.395558  0.067093 -0.707439 -0.244784

# %%
df.plot.bar(stacked = True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
print(df)
df.plot(kind = 'box')
# Out:
#           a         b         c         d
# 0 -0.789873 -0.279090 -0.073126 -0.144016
# 1 -1.073413  0.539372 -1.980382 -0.155633
# 2  1.444905 -0.286589  0.089124  0.618263
# 3 -0.989048  0.366496  0.366710 -0.886597
# 4 -0.158315  1.234150 -2.260861 -0.250485
# 5 -0.680543  1.769154  0.479883 -0.799829
# 6 -0.420079 -0.044555 -0.719077  1.293920
# 7 -0.608142 -0.063218 -0.624348  0.134243
# 8 -0.154030 -1.403449 -0.762853  1.919565
# 9  0.395558  0.067093 -0.707439 -0.244784
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.303298   0.189936  -0.619237   0.148465
# std     0.755490   0.872907   0.916892   0.890207
# min    -1.073413  -1.403449  -2.260861  -0.886597
# 25%    -0.762540  -0.225122  -0.751909  -0.249060
# 50%    -0.514111   0.011269  -0.665894  -0.149825
# 75%    -0.155101   0.496153   0.048561   0.497258
# max     1.444905   1.769154   0.479883   1.919565

# %%
print(df)
df.describe()
df.plot(kind = 'box', figsize = (10,5), vert=False)
# Out:
#           a         b         c         d
# 0 -0.789873 -0.279090 -0.073126 -0.144016
# 1 -1.073413  0.539372 -1.980382 -0.155633
# 2  1.444905 -0.286589  0.089124  0.618263
# 3 -0.989048  0.366496  0.366710 -0.886597
# 4 -0.158315  1.234150 -2.260861 -0.250485
# 5 -0.680543  1.769154  0.479883 -0.799829
# 6 -0.420079 -0.044555 -0.719077  1.293920
# 7 -0.608142 -0.063218 -0.624348  0.134243
# 8 -0.154030 -1.403449 -0.762853  1.919565
# 9  0.395558  0.067093 -0.707439 -0.244784
# <AxesSubplot:>

# %% [markdown]
# # Area and Scatter Plot

# %%
df = sns.load_dataset('iris')
df = df.drop(['species'], axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', stacked = False, alpha = .5)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_width', y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_width', y='petal_width', c = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
ax = df.plot.scatter(x='sepal_width', y='petal_width', color='g', label='Width')
df.plot.scatter(x='sepal_length', y='petal_length', ax = ax, color='#ffe05d',  label='Length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # Hex and Pie Plot

# %%
df.plot.hexbin(x='sepal_length', y='petal_length', gridsize=10, C='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
print(df)
df.iloc[0]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot.pie(figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True, figsize= (30,30), fontsize=25, autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %% [markdown]
# # Subplot

# %%
df.plot(subplots=True, sharex= False, layout = (2,4), figsize=(15,7))
plt.tight_layout()
