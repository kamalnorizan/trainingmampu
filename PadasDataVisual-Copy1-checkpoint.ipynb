# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2021-01-01', periods = 1000), columns=['value'])

# %%
df['value']=df['value'].cumsum()
df
# Out:
#                 value
# 2021-01-01  -1.138794
# 2021-01-02  -1.582394
# 2021-01-03  -2.119243
# 2021-01-04  -1.931120
# 2021-01-05  -3.463763
# ...               ...
# 2023-09-23 -33.024277
# 2023-09-24 -32.857915
# 2023-09-25 -35.366443
# 2023-09-26 -34.372115
# 2023-09-27 -34.425348
#
# [1000 rows x 1 columns]

# %%
ts = pd.Series(randn(1000), pd.date_range('2021-01-01', periods = 1000))

# %%
ts
# Out:
# 2021-01-01    0.975692
# 2021-01-02    0.193501
# 2021-01-03    1.502287
# 2021-01-04   -0.390225
# 2021-01-05    0.773782
#                 ...
# 2023-09-23    1.303540
# 2023-09-24    0.038236
# 2023-09-25   -0.628242
# 2023-09-26    0.119552
# 2023-09-27   -0.279946
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()
ts
# Out:
# 2021-01-01     0.975692
# 2021-01-02     1.169193
# 2021-01-03     2.671480
# 2021-01-04     2.281255
# 2021-01-05     3.055037
#                 ...
# 2023-09-23   -25.375269
# 2023-09-24   -25.337033
# 2023-09-25   -25.965276
# 2023-09-26   -25.845724
# 2023-09-27   -26.125670
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts.plot(figsize = (14,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (14,5))
# Out:
# <AxesSubplot:>
