# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame({'value1':randn(1000),'value2':randn(1000),'value3':randn(1000),'value4':randn(1000)}, index = pd.date_range('2021-01-01', periods = 1000), columns=['value1','value2','value3','value4'])

# %%
df['value1']=df['value1'].cumsum()
df['value2']=df['value2'].cumsum()
df['value3']=df['value3'].cumsum()
df['value4']=df['value4'].cumsum()
df
# Out:
#               value1     value2     value3     value4
# 2021-01-01 -0.808246  -1.071931   0.063249   1.063939
# 2021-01-02 -1.165985  -1.778200   1.277799   0.993223
# 2021-01-03 -0.645959   0.211084   0.966844   0.606599
# 2021-01-04 -1.089546  -1.070585   0.015956  -0.113949
# 2021-01-05 -1.836017  -1.215848   0.432505  -0.616408
# ...              ...        ...        ...        ...
# 2023-09-23 -2.859046  16.130476 -53.162598  22.896171
# 2023-09-24 -3.279979  16.796985 -51.944094  21.459278
# 2023-09-25 -2.565246  16.190717 -52.591442  21.835270
# 2023-09-26 -2.454461  16.861390 -51.107026  21.530714
# 2023-09-27 -2.069647  14.726880 -50.970122  20.618399
#
# [1000 rows x 4 columns]

# %%
ts = pd.Series(randn(1000), pd.date_range('2021-01-01', periods = 1000))

# %%
ts
# Out:
# 2021-01-01   -0.195975
# 2021-01-02    3.052977
# 2021-01-03    1.426001
# 2021-01-04   -1.217177
# 2021-01-05   -0.292740
#                 ...
# 2023-09-23   -0.016933
# 2023-09-24   -0.381968
# 2023-09-25    0.551744
# 2023-09-26   -2.110433
# 2023-09-27   -0.744296
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()
ts
# Out:
# 2021-01-01    -0.195975
# 2021-01-02     2.857002
# 2021-01-03     4.283003
# 2021-01-04     3.065826
# 2021-01-05     2.773086
#                 ...
# 2023-09-23    39.433153
# 2023-09-24    39.051185
# 2023-09-25    39.602929
# 2023-09-26    37.492495
# 2023-09-27    36.748199
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts.plot(figsize = (14,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (14,5), legend=False, title="Random Number Line Plot")
# Out:
# <AxesSubplot:title={'center':'Random Number Line Plot'}>
